# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-be563438-f7ba-4d45-b010-be3f02e03124" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be563438-f7ba-4d45-b010-be3f02e03124">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("E-commerce sales - Sheet1.csv")

df.head()
# Out:
#   Order_ID Order_Date Customer_Name     Category Sub_Category       Product  \
# 0   ORD001   1/2/2026         Rahul  Electronics      Mobiles    Smartphone
# 1   ORD002   1/3/2026         Priya    Furniture       Chairs  Office Chair
# 2   ORD003   1/4/2026          Amit     Clothing       Shirts  Formal Shirt
# 3   ORD004   1/5/2026          Neha  Electronics      Laptops        Laptop
# 4   ORD005   1/7/2026          Ravi    Furniture       Tables   Study Table
#
#    Quantity      Sales  Discount  Profit       City          State  \
# 0         2  36,000.00      20.0    5832      Noida  Uttar Pradesh
# 1         1   7,500.00      20.0     712      Delhi          Delhi
# 2         3   4,500.00      20.0     810     Bijnor  Uttar Pradesh
# 3         1  50,000.00      20.0   10625  Ghaziabad  Uttar Pradesh
# 4         2  12,000.00      20.0    2160     Meerut  Uttar Pradesh
#
#   Payment_Mode
# 0          UPI
# 1         Card
# 2         Cash
# 3          UPI
# 4         Card

# %%
print("Rows and Columns:")
print(df.shape)

print("\nColumn Names:")
print(df.columns.tolist())

print("\nData Information:")
df.info()
# Out:
# Rows and Columns:
# (200, 13)
#
# Column Names:
# ['Order_ID', 'Order_Date', 'Customer_Name', 'Category', 'Sub_Category', 'Product', 'Quantity', 'Sales', 'Discount', 'Profit', 'City', 'State', 'Payment_Mode']
#
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       200 non-null    object
#  1   Order_Date     200 non-null    object
#  2   Customer_Name  200 non-null    object
#  3   Category       200 non-null    object
#  4   Sub_Category   200 non-null    object
#  5   Product        200 non-null    object
#  6   Quantity       200 non-null    int64
#  7   Sales          200 non-null    object
#  8   Discount       200 non-null    float64
#  9   Profit         200 non-null    int64
#  10  City           200 non-null    object
#  11  State          200 non-null    object
# ...

# %%
print("Missing Values in Each Column:")
print(df.isnull().sum())
# Out:
# Missing Values in Each Column:
# Order_ID         0
# Order_Date       0
# Customer_Name    0
# Category         0
# Sub_Category     0
# Product          0
# Quantity         0
# Sales            0
# Discount         0
# Profit           0
# City             0
# State            0
# Payment_Mode     0
# dtype: int64

# %%
print("Total Duplicate Rows:")
print(df.duplicated().sum())
# Out:
# Total Duplicate Rows:
# 0

# %%
print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# Order_ID          object
# Order_Date        object
# Customer_Name     object
# Category          object
# Sub_Category      object
# Product           object
# Quantity           int64
# Sales             object
# Discount         float64
# Profit             int64
# City              object
# State             object
# Payment_Mode      object
# dtype: object

# %%
print("Numerical Data Summary:")
df.describe()
# Out:
# Numerical Data Summary:
#          Quantity    Discount        Profit
# count  200.000000  200.000000    200.000000
# mean     2.400000    9.575000   2086.540000
# std      1.231904    6.355813   3474.796887
# min      1.000000    0.000000     51.000000
# 25%      1.000000    5.000000    366.500000
# 50%      2.000000   10.000000    787.500000
# 75%      3.000000   15.000000   1752.250000
# max      5.000000   20.000000  18000.000000

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)

print("Category-wise Sales:")
print(category_sales)
# Out:
# Category-wise Sales:
# Category
# Furniture          7,500.0012,000.008,500.004,500.0015,000.006,00...
# Office Supplies    400.001,500.001,400.002,100.00400.002,000.001,...
# Clothing           4,500.003,600.006,400.002,200.003,000.001,800....
# Electronics        36,000.0050,000.005,000.0018,000.003,600.0050,...
# Name: Sales, dtype: object

# %%
category_profit = df.groupby("Category")["Profit"].sum().sort_values(ascending=False)

print("Category-wise Profit:")
print(category_profit)
# Out:
# Category-wise Profit:
# Category
# Electronics        299845
# Furniture           74667
# Clothing            33300
# Office Supplies      9496
# Name: Profit, dtype: int64

# %%
subcategory_profit = (
    df.groupby("Sub_Category")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

print("Sub-Category-wise Profit:")
print(subcategory_profit)
# Out:
# Sub-Category-wise Profit:
# Sub_Category
# Laptops        201125
# Mobiles         81232
# Tables          24375
# Bookcases       23575
# Chairs          21228
# Accessories     17488
# Jackets         13323
# Shirts           7513
# Trousers         7374
# Furnishings      5489
# T-Shirts         5090
# Paper            3439
# Storage          3394
# Binders          2131
# Pens              532
# Name: Profit, dtype: int64

# %%
top_products_sales = (
    df.groupby("Product")["Sales"]
      .sum()
      .sort_values(ascending=False)
      .head(10)
)

print("Top 10 Products by Sales:")
print(top_products_sales)
# Out:
# Top 10 Products by Sales:
# Product
# Bookshelf       8,500.0017,000.008,500.008,500.0017,000.008,50...
# Office Chair    7,500.0015,000.007,500.007,500.0015,000.0022,5...
# Jacket          6,400.003,200.006,400.009,600.003,200.006,400....
# Laptop          50,000.0050,000.00100,000.0050,000.0050,000.00...
# Headphones      5,000.002,500.005,000.007,500.002,500.005,000....
# Ball Pen        400.00400.00320.00400.00400.00320.00400.00400....
# Desk Lamp       4,500.006,000.003,000.004,500.006,000.003,000....
# Formal Shirt    4,500.003,000.006,000.001,500.003,000.004,500....
# Smartphone      36,000.0018,000.0054,000.0018,000.0036,000.001...
# Keyboard        3,600.005,400.003,600.007,200.003,600.005,400....
# Name: Sales, dtype: object

# %%
top_products_profit = (
    df.groupby("Product")["Profit"]
      .sum()
      .sort_values(ascending=False)
      .head(10)
)

print("Top 10 Products by Profit:")
print(top_products_profit)
# Out:
# Top 10 Products by Profit:
# Product
# Laptop             201125
# Smartphone          81232
# Study Table         24375
# Bookshelf           23575
# Office Chair        21228
# Jacket              13323
# Headphones           8835
# Keyboard             8653
# Formal Shirt         7513
# Formal Trousers      7374
# Name: Profit, dtype: int64

# %%
state_sales = (
    df.groupby("State")["Sales"]
      .sum()
      .sort_values(ascending=False)
)

print("State-wise Sales:")
print(state_sales)
# Out:
# State-wise Sales:
# State
# Delhi            7,500.0018,000.0050,000.002,500.001,050.002,70...
# Haryana          5,000.003,600.001,800.006,000.006,400.002,800....
# Uttar Pradesh    36,000.004,500.0050,000.0012,000.00400.008,500...
# Rajasthan        3,600.002,100.003,200.0012,000.006,600.008,500...
# Uttarakhand      1,500.006,000.001,750.004,500.002,100.003,500....
# Name: Sales, dtype: object

# %%
state_profit = (
    df.groupby("State")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

print("State-wise Profit:")
print(state_profit)
# Out:
# State-wise Profit:
# State
# Uttar Pradesh    255240
# Delhi             72731
# Haryana           43488
# Rajasthan         42381
# Uttarakhand        3468
# Name: Profit, dtype: int64

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

monthly_sales = (
    df.groupby(df["Order_Date"].dt.month)["Sales"]
      .sum()
      .sort_index()
)

print("Monthly Sales:")
print(monthly_sales)
# Out:
# Monthly Sales:
# Order_Date
# 1     36,000.007,500.004,500.0050,000.0012,000.00400...
# 2     6,000.0054,000.00400.001,800.002,500.0017,000....
# 3     5,000.002,500.008,500.0050,000.006,400.00320.0...
# 4     18,000.0015,000.002,200.00400.00100,000.006,00...
# 5     3,600.0012,000.00900.0054,000.002,500.008,500....
# 6     2,500.0015,000.009,600.0050,000.002,000.0017,0...
# 7     54,000.006,000.003,000.007,200.001,400.008,500...
# 8     3,600.007,500.004,400.0036,000.001,500.0017,00...
# 9     50,000.003,000.006,400.002,500.002,800.008,500...
# 10    12,000.003,600.0050,000.002,100.007,500.007,20...
# Name: Sales, dtype: object

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

monthly_sales = (
    df.groupby(df["Order_Date"].dt.month)["Sales"]
      .sum()
      .sort_index()
)

print("Monthly Sales:")
print(monthly_sales)
# Out:
# Monthly Sales:
# Order_Date
# 1     36,000.007,500.004,500.0050,000.0012,000.00400...
# 2     6,000.0054,000.00400.001,800.002,500.0017,000....
# 3     5,000.002,500.008,500.0050,000.006,400.00320.0...
# 4     18,000.0015,000.002,200.00400.00100,000.006,00...
# 5     3,600.0012,000.00900.0054,000.002,500.008,500....
# 6     2,500.0015,000.009,600.0050,000.002,000.0017,0...
# 7     54,000.006,000.003,000.007,200.001,400.008,500...
# 8     3,600.007,500.004,400.0036,000.001,500.0017,00...
# 9     50,000.003,000.006,400.002,500.002,800.008,500...
# 10    12,000.003,600.0050,000.002,100.007,500.007,20...
# Name: Sales, dtype: object

# %%
top_customers_sales = (
    df.groupby("Customer_Name")["Sales"]
      .sum()
      .sort_values(ascending=False)
      .head(10)
)

print("Top 10 Customers by Sales:")
print(top_customers_sales)
# Out:
# Top 10 Customers by Sales:
# Customer_Name
# Vikas     8,500.00100,000.007,500.001,400.006,000.003,00...
# Priya     7,500.0054,000.008,500.0015,000.0012,000.0015,...
# Anjali    6,400.004,400.001,500.004,500.006,400.003,000....
# Manish    50,000.002,700.001,000.001,400.00700.001,750.0...
# Neha      50,000.001,800.006,400.00400.0054,000.0050,000...
# Ankit     5,000.002,000.0036,000.003,000.005,000.004,400...
# Pooja     400.0017,000.003,000.006,000.008,500.0017,000....
# Arjun     4,500.005,400.0018,000.0017,000.007,500.0018,0...
# Amit      4,500.00400.0050,000.002,200.00900.009,600.003...
# Rahul     36,000.006,000.002,500.0018,000.003,600.002,50...
# Name: Sales, dtype: object

# %%
top_customers_profit = (
    df.groupby("Customer_Name")["Profit"]
      .sum()
      .sort_values(ascending=False)
      .head(10)
)

print("Top 10 Customers by Profit:")
print(top_customers_profit)
# Out:
# Top 10 Customers by Profit:
# Customer_Name
# Ankit     42319
# Neha      41739
# Simran    40741
# Rohit     40730
# Rahul     33723
# Shweta    31407
# Vikas     25343
# Ravi      22579
# Priya     19884
# Arjun     19572
# Name: Profit, dtype: int64

# %%
category_quantity = (
    df.groupby("Category")["Quantity"]
      .sum()
      .sort_values(ascending=False)
)

print("Category-wise Quantity:")
print(category_quantity)
# Out:
# Category-wise Quantity:
# Category
# Office Supplies    158
# Clothing           118
# Electronics        107
# Furniture           97
# Name: Quantity, dtype: int64

# %%
discount_analysis = (
    df.groupby("Discount")[["Sales", "Profit"]]
      .sum()
      .sort_index()
)

print("Discount-wise Sales & Profit:")
print(discount_analysis)
# Out:
# Discount-wise Sales & Profit:
#                                                       Sales  Profit
# Discount
# 0.0       2,700.0012,000.00400.00100,000.001,500.0022,50...   74191
# 5.0       1,400.008,500.00100,000.006,600.004,500.002,50...   93900
# 10.0      100,000.006,000.003,000.007,200.001,400.004,50...  123499
# 15.0      100,000.006,000.001,050.004,400.005,400.007,50...   71749
# 20.0      36,000.007,500.004,500.0050,000.0012,000.00400...   53969

# %%
city_sales = (
    df.groupby("City")["Sales"]
      .sum()
      .sort_values(ascending=False)
)

print("City-wise Sales:")
print(city_sales)
# Out:
# City-wise Sales:
# City
# Agra         8,500.003,000.00100,000.005,000.007,500.009,60...
# Delhi        7,500.0018,000.0050,000.002,500.001,050.002,70...
# Ghaziabad    50,000.004,500.0054,000.005,400.008,500.0018,0...
# Gurugram     5,000.003,600.001,800.006,000.006,400.002,800....
# Bijnor       4,500.002,200.0017,000.001,400.003,000.001,800...
# Noida        36,000.00400.006,400.0015,000.006,000.002,000....
# Jaipur       3,600.002,100.003,200.0012,000.006,600.008,500...
# Meerut       12,000.001,400.00400.007,500.0050,000.0050,000...
# Dehradun     1,500.006,000.001,750.004,500.002,100.003,500....
# Name: Sales, dtype: object

# %%
city_profit = (
    df.groupby("City")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

print("City-wise Profit:")
print(city_profit)
# Out:
# City-wise Profit:
# City
# Noida        97501
# Delhi        72731
# Meerut       55479
# Ghaziabad    49369
# Gurugram     43488
# Jaipur       42381
# Agra         32906
# Bijnor       19985
# Dehradun      3468
# Name: Profit, dtype: int64

# %%
df["Sales"] = pd.to_numeric(df["Sales"], errors="coerce")
df["Profit"] = pd.to_numeric(df["Profit"], errors="coerce")
df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")

print(df[["Sales", "Profit", "Quantity"]].dtypes)
# Out:
# Sales       float64
# Profit        int64
# Quantity      int64
# dtype: object

# %%
total_records = len(df)
total_quantity = df["Quantity"].sum()
total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()
average_sales = df["Sales"].mean()
profit_margin = (total_profit / total_sales) * 100

print("E-Commerce Sales Analysis - KPI Summary")
print("----------------------------------------")
print("Total Records:", total_records)
print("Total Quantity:", total_quantity)
print("Total Sales:", total_sales)
print("Total Profit:", total_profit)
print("Average Sales:", round(average_sales, 2))
print("Profit Margin:", round(profit_margin, 2), "%")
# Out:
# E-Commerce Sales Analysis - KPI Summary
# ----------------------------------------
# Total Records: 200
# Total Quantity: 480
# Total Sales: 5940.0
# Total Profit: 417308
# Average Sales: 495.0
# Profit Margin: 7025.39 %

# %%
loss_products = (
    df.groupby("Product")["Profit"]
      .sum()
      .sort_values()
)

loss_products = loss_products[loss_products < 0]

print("Loss-Making Products:")
print(loss_products)
# Out:
# Loss-Making Products:
# Series([], Name: Profit, dtype: int64)

# %%
category_discount = (
    df.groupby("Category")["Discount"]
      .mean()
      .sort_values(ascending=False)
)

print("Category-wise Average Discount:")
print(category_discount)
# Out:
# Category-wise Average Discount:
# Category
# Office Supplies    9.634146
# Furniture          9.600000
# Electronics        9.576271
# Clothing           9.500000
# Name: Discount, dtype: float64

# %%
correlation = df["Sales"].corr(df["Profit"])

print("Sales-Profit Correlation:", round(correlation, 2))
# Out:
# Sales-Profit Correlation: 0.98

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.hist(df["Sales"].dropna(), bins=20)
plt.xlabel("Sales")
plt.ylabel("Number of Orders")
plt.title("Sales Distribution")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df["Profit"].dropna(), bins=20)
plt.xlabel("Profit")
plt.ylabel("Number of Orders")
plt.title("Profit Distribution")
plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)

print(category_sales)
# Out:
# Category
# Office Supplies    4140.0
# Clothing           1800.0
# Electronics           0.0
# Furniture             0.0
# Name: Sales, dtype: float64

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
plt.bar(category_sales.index, category_sales.values)
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.title("Category-wise Sales")
plt.xticks(rotation=45)
plt.show()

# %%
category_profit = df.groupby("Category")["Profit"].sum().sort_values(ascending=False)

print(category_profit)
# Out:
# Category
# Electronics        299845
# Furniture           74667
# Clothing            33300
# Office Supplies      9496
# Name: Profit, dtype: int64

# %%
plt.figure(figsize=(8, 5))

plt.bar(category_profit.index, category_profit.values)

plt.xlabel("Category")
plt.ylabel("Total Profit")
plt.title("Category-wise Profit")

plt.xticks(rotation=45)
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Order_ID', 'Order_Date', 'Customer_Name', 'Category', 'Sub_Category', 'Product', 'Quantity', 'Sales', 'Discount', 'Profit', 'City', 'State', 'Payment_Mode']

# %%
subcategory_col = [col for col in df.columns if "sub" in col.lower() and "categor" in col.lower()][0]

subcategory_sales = df.groupby(subcategory_col)["Sales"].sum().sort_values(ascending=False)

print(subcategory_sales)
# Out:
# Sub_Category
# Pens           3440.0
# T-Shirts       1800.0
# Binders         700.0
# Chairs            0.0
# Furnishings       0.0
# Accessories       0.0
# Bookcases         0.0
# Laptops           0.0
# Jackets           0.0
# Paper             0.0
# Mobiles           0.0
# Shirts            0.0
# Storage           0.0
# Tables            0.0
# Trousers          0.0
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10, 6))

plt.bar(subcategory_sales.index, subcategory_sales.values)

plt.xlabel("Sub-Category")
plt.ylabel("Total Sales")
plt.title("Sub-Category-wise Sales")

plt.xticks(rotation=45)
plt.show()

# %%
subcategory_profit = df.groupby(subcategory_col)["Profit"].sum().sort_values(ascending=False)

print(subcategory_profit)
# Out:
# Sub_Category
# Laptops        201125
# Mobiles         81232
# Tables          24375
# Bookcases       23575
# Chairs          21228
# Accessories     17488
# Jackets         13323
# Shirts           7513
# Trousers         7374
# Furnishings      5489
# T-Shirts         5090
# Paper            3439
# Storage          3394
# Binders          2131
# Pens              532
# Name: Profit, dtype: int64

# %%
plt.figure(figsize=(10, 6))

plt.bar(subcategory_profit.index, subcategory_profit.values)

plt.xlabel("Sub-Category")
plt.ylabel("Total Profit")
plt.title("Sub-Category-wise Profit")

plt.xticks(rotation=45)
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Order_ID', 'Order_Date', 'Customer_Name', 'Category', 'Sub_Category', 'Product', 'Quantity', 'Sales', 'Discount', 'Profit', 'City', 'State', 'Payment_Mode']

# %%
customer_col = [col for col in df.columns if "customer" in col.lower()][0]

top_customers = df.groupby(customer_col)["Sales"].sum().sort_values(ascending=False).head(10)

print(top_customers)
# Out:
# Customer_Name
# Amit      1300.0
# Manish    1100.0
# Anjali     900.0
# Nitin      720.0
# Pooja      400.0
# Simran     400.0
# Neha       400.0
# Kavita     400.0
# Ravi       320.0
# Ankit        0.0
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10, 6))

plt.barh(top_customers.index, top_customers.values)

plt.xlabel("Total Sales")
plt.ylabel("Customer")
plt.title("Top 10 Customers by Sales")

plt.gca().invert_yaxis()

plt.show()

# %%
top_profit_customers = df.groupby(customer_col)["Profit"].sum().sort_values(ascending=False).head(10)

print(top_profit_customers)
# Out:
# Customer_Name
# Ankit     42319
# Neha      41739
# Simran    40741
# Rohit     40730
# Rahul     33723
# Shweta    31407
# Vikas     25343
# Ravi      22579
# Priya     19884
# Arjun     19572
# Name: Profit, dtype: int64

# %%
plt.figure(figsize=(10, 6))

plt.barh(top_profit_customers.index, top_profit_customers.values)

plt.xlabel("Total Profit")
plt.ylabel("Customer")
plt.title("Top 10 Customers by Profit")

plt.gca().invert_yaxis()

plt.show()

# %%
city_sales = df.groupby("City")["Sales"].sum().sort_values(ascending=False).head(10)

print(city_sales)
# Out:
# City
# Meerut       1700.0
# Delhi        1420.0
# Noida        1300.0
# Gurugram     1120.0
# Dehradun      400.0
# Agra            0.0
# Bijnor          0.0
# Ghaziabad       0.0
# Jaipur          0.0
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10, 6))

plt.barh(city_sales.index, city_sales.values)

plt.xlabel("Total Sales")
plt.ylabel("City")
plt.title("Top 10 Cities by Sales")

plt.gca().invert_yaxis()

plt.show()

# %%
city_profit = df.groupby("City")["Profit"].sum().sort_values(ascending=False).head(10)

print(city_profit)
# Out:
# City
# Noida        97501
# Delhi        72731
# Meerut       55479
# Ghaziabad    49369
# Gurugram     43488
# Jaipur       42381
# Agra         32906
# Bijnor       19985
# Dehradun      3468
# Name: Profit, dtype: int64

# %%
plt.figure(figsize=(10, 6))

plt.barh(city_profit.index, city_profit.values)

plt.xlabel("Total Profit")
plt.ylabel("City")
plt.title("Top 10 Cities by Profit")

plt.gca().invert_yaxis()

plt.show()

# %%
state_sales = df.groupby("State")["Sales"].sum().sort_values(ascending=False).head(10)

print(state_sales)
# Out:
# State
# Uttar Pradesh    3000.0
# Delhi            1420.0
# Haryana          1120.0
# Uttarakhand       400.0
# Rajasthan           0.0
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10, 6))

plt.barh(state_sales.index, state_sales.values)

plt.xlabel("Total Sales")
plt.ylabel("State")
plt.title("Top 10 States by Sales")

plt.gca().invert_yaxis()

plt.show()

# %%
state_profit = df.groupby("State")["Profit"].sum().sort_values(ascending=False).head(10)

print(state_profit)
# Out:
# State
# Uttar Pradesh    255240
# Delhi             72731
# Haryana           43488
# Rajasthan         42381
# Uttarakhand        3468
# Name: Profit, dtype: int64

# %%
plt.figure(figsize=(10, 6))

plt.barh(state_profit.index, state_profit.values)

plt.xlabel("Total Profit")
plt.ylabel("State")
plt.title("Top 10 States by Profit")

plt.gca().invert_yaxis()

plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Order_ID', 'Order_Date', 'Customer_Name', 'Category', 'Sub_Category', 'Product', 'Quantity', 'Sales', 'Discount', 'Profit', 'City', 'State', 'Payment_Mode']

# %%
discount_analysis = df.groupby("Discount")[["Sales", "Profit"]].sum().sort_index()

print(discount_analysis)
# Out:
#            Sales  Profit
# Discount
# 0.0        800.0   74191
# 5.0       1300.0   93900
# 10.0      2320.0  123499
# 15.0       720.0   71749
# 20.0       800.0   53969

# %%
plt.figure(figsize=(8, 5))

plt.bar(discount_analysis.index.astype(str), discount_analysis["Profit"])

plt.xlabel("Discount")
plt.ylabel("Total Profit")
plt.title("Discount vs Profit")

plt.show()

# %%
quantity_analysis = df.groupby("Quantity")[["Sales", "Profit"]].sum().sort_index()

print(quantity_analysis)
# Out:
#            Sales  Profit
# Quantity
# 1         1800.0  161785
# 2          700.0  180810
# 3            0.0   57976
# 4          640.0   11999
# 5         2800.0    4738

# %%
plt.figure(figsize=(8, 5))

plt.bar(quantity_analysis.index.astype(str), quantity_analysis["Sales"])

plt.xlabel("Quantity")
plt.ylabel("Total Sales")
plt.title("Quantity vs Sales")

plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Order_ID', 'Order_Date', 'Customer_Name', 'Category', 'Sub_Category', 'Product', 'Quantity', 'Sales', 'Discount', 'Profit', 'City', 'State', 'Payment_Mode']

# %%
print("Total Orders:", len(df))
print("Total Sales:", round(df["Sales"].sum(), 2))
print("Total Profit:", round(df["Profit"].sum(), 2))
print("Total Quantity:", df["Quantity"].sum())
print("Average Sales per Order:", round(df["Sales"].mean(), 2))
print("Average Profit per Order:", round(df["Profit"].mean(), 2))
# Out:
# Total Orders: 200
# Total Sales: 5940.0
# Total Profit: 417308
# Total Quantity: 480
# Average Sales per Order: 495.0
# Average Profit per Order: 2086.54

# %%
total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()

profit_margin = (total_profit / total_sales) * 100

print("Overall Profit Margin:", round(profit_margin, 2), "%")
# Out:
# Overall Profit Margin: 7025.39 %

# %%
loss_orders = df[df["Profit"] < 0]

print("Loss-Making Orders:", len(loss_orders))
# Out:
# Loss-Making Orders: 0

# %%
profitable_orders = (df["Profit"] > 0).sum()
loss_orders = (df["Profit"] < 0).sum()
zero_profit_orders = (df["Profit"] == 0).sum()

print("Profitable Orders:", profitable_orders)
print("Loss Orders:", loss_orders)
print("Zero Profit Orders:", zero_profit_orders)
# Out:
# Profitable Orders: 200
# Loss Orders: 0
# Zero Profit Orders: 0

# %%
highest_sales_order = df.loc[df["Sales"].idxmax()]

print(highest_sales_order)
# Out:
# Order_ID                      ORD083
# Order_Date       2026-05-04 00:00:00
# Customer_Name                   Amit
# Category                    Clothing
# Sub_Category                T-Shirts
# Product               Casual T-Shirt
# Quantity                           1
# Sales                          900.0
# Discount                        10.0
# Profit                           153
# City                          Meerut
# State                  Uttar Pradesh
# Payment_Mode                    Cash
# Name: 82, dtype: object

# %%
highest_profit_order = df.loc[df["Profit"].idxmax()]

print(highest_profit_order)
# Out:
# Order_ID                      ORD029
# Order_Date       2026-02-12 00:00:00
# Customer_Name                  Vikas
# Category                 Electronics
# Sub_Category                 Laptops
# Product                       Laptop
# Quantity                           2
# Sales                            NaN
# Discount                        15.0
# Profit                         18000
# City                            Agra
# State                  Uttar Pradesh
# Payment_Mode                    Card
# Name: 28, dtype: object

# %%
highest_loss_order = df.loc[df["Profit"].idxmin()]

print(highest_loss_order)
# Out:
# Order_ID                      ORD064
# Order_Date       2026-04-06 00:00:00
# Customer_Name                   Neha
# Category             Office Supplies
# Sub_Category                    Pens
# Product                     Ball Pen
# Quantity                           5
# Sales                          400.0
# Discount                        15.0
# Profit                            51
# City                        Gurugram
# State                        Haryana
# Payment_Mode                    Card
# Name: 63, dtype: object

# %%
summary = df[["Sales", "Profit"]].sum()

plt.figure(figsize=(8, 5))

plt.bar(summary.index, summary.values)

plt.xlabel("Metric")
plt.ylabel("Amount")
plt.title("Total Sales vs Total Profit")

plt.show()

# %%
print("===== E-COMMERCE SALES ANALYSIS SUMMARY =====")

print("Total Orders:", len(df))
print("Total Sales:", round(df["Sales"].sum(), 2))
print("Total Profit:", round(df["Profit"].sum(), 2))
print("Total Quantity:", df["Quantity"].sum())

print("Average Sales per Order:", round(df["Sales"].mean(), 2))
print("Average Profit per Order:", round(df["Profit"].mean(), 2))

print("Profitable Orders:", (df["Profit"] > 0).sum())
print("Loss Orders:", (df["Profit"] < 0).sum())

print("Highest Sales:", round(df["Sales"].max(), 2))
print("Highest Profit:", round(df["Profit"].max(), 2))
print("Highest Loss:", round(df["Profit"].min(), 2))
# Out:
# ===== E-COMMERCE SALES ANALYSIS SUMMARY =====
# Total Orders: 200
# Total Sales: 5940.0
# Total Profit: 417308
# Total Quantity: 480
# Average Sales per Order: 495.0
# Average Profit per Order: 2086.54
# Profitable Orders: 200
# Loss Orders: 0
# Highest Sales: 900.0
# Highest Profit: 18000
# Highest Loss: 51

# %%
best_category = df.groupby("Category")["Sales"].sum().idxmax()
best_category_sales = df.groupby("Category")["Sales"].sum().max()

best_city = df.groupby("City")["Sales"].sum().idxmax()
best_city_sales = df.groupby("City")["Sales"].sum().max()

best_state = df.groupby("State")["Sales"].sum().idxmax()
best_state_sales = df.groupby("State")["Sales"].sum().max()

print("===== KEY BUSINESS INSIGHTS =====")

print("Highest Sales Category:", best_category)
print("Category Sales:", round(best_category_sales, 2))

print("Highest Sales City:", best_city)
print("City Sales:", round(best_city_sales, 2))

print("Highest Sales State:", best_state)
print("State Sales:", round(best_state_sales, 2))
# Out:
# ===== KEY BUSINESS INSIGHTS =====
# Highest Sales Category: Office Supplies
# Category Sales: 4140.0
# Highest Sales City: Meerut
# City Sales: 1700.0
# Highest Sales State: Uttar Pradesh
# State Sales: 3000.0

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nColumn Names:")
print(df.columns.tolist())

print("\nFirst 5 Rows:")
print(df.head())
# Out:
# Rows: 200
# Columns: 13
#
# Column Names:
# ['Order_ID', 'Order_Date', 'Customer_Name', 'Category', 'Sub_Category', 'Product', 'Quantity', 'Sales', 'Discount', 'Profit', 'City', 'State', 'Payment_Mode']
#
# First 5 Rows:
#   Order_ID Order_Date Customer_Name     Category Sub_Category       Product  \
# 0   ORD001 2026-01-02         Rahul  Electronics      Mobiles    Smartphone
# 1   ORD002 2026-01-03         Priya    Furniture       Chairs  Office Chair
# 2   ORD003 2026-01-04          Amit     Clothing       Shirts  Formal Shirt
# 3   ORD004 2026-01-05          Neha  Electronics      Laptops        Laptop
# 4   ORD005 2026-01-07          Ravi    Furniture       Tables   Study Table
#
#    Quantity  Sales  Discount  Profit       City          State Payment_Mode
# 0         2    NaN      20.0    5832      Noida  Uttar Pradesh          UPI
# 1         1    NaN      20.0     712      Delhi          Delhi         Card
# ...

# %%
df.to_csv("ecommerce_cleaned_data.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
final_summary = pd.DataFrame({
    "Metric": [
        "Total Orders",
        "Total Sales",
        "Total Profit",
        "Total Quantity",
        "Profit Margin (%)",
        "Profitable Orders",
        "Loss Orders"
    ],
    "Value": [
        len(df),
        round(df["Sales"].sum(), 2),
        round(df["Profit"].sum(), 2),
        df["Quantity"].sum(),
        round((df["Profit"].sum() / df["Sales"].sum()) * 100, 2),
        (df["Profit"] > 0).sum(),
        (df["Profit"] < 0).sum()
    ]
})

print(final_summary)
# Out:
#               Metric      Value
# 0       Total Orders     200.00
# 1        Total Sales    5940.00
# 2       Total Profit  417308.00
# 3     Total Quantity     480.00
# 4  Profit Margin (%)    7025.39
# 5  Profitable Orders     200.00
# 6        Loss Orders       0.00

# %%
final_summary.to_csv("ecommerce_final_summary.csv", index=False)

print("Final summary saved successfully!")
# Out:
# Final summary saved successfully!

# %%
print("===== FINAL BUSINESS INSIGHTS =====")

print("1. Total Orders:", len(df))
print("2. Total Sales:", round(df["Sales"].sum(), 2))
print("3. Total Profit:", round(df["Profit"].sum(), 2))

profit_margin = (df["Profit"].sum() / df["Sales"].sum()) * 100
print("4. Profit Margin:", round(profit_margin, 2), "%")

print("5. Profitable Orders:", (df["Profit"] > 0).sum())
print("6. Loss Orders:", (df["Profit"] < 0).sum())

best_category = df.groupby("Category")["Sales"].sum().idxmax()
print("7. Highest Sales Category:", best_category)

best_city = df.groupby("City")["Sales"].sum().idxmax()
print("8. Highest Sales City:", best_city)

best_state = df.groupby("State")["Sales"].sum().idxmax()
print("9. Highest Sales State:", best_state)
# Out:
# ===== FINAL BUSINESS INSIGHTS =====
# 1. Total Orders: 200
# 2. Total Sales: 5940.0
# 3. Total Profit: 417308
# 4. Profit Margin: 7025.39 %
# 5. Profitable Orders: 200
# 6. Loss Orders: 0
# 7. Highest Sales Category: Office Supplies
# 8. Highest Sales City: Meerut
# 9. Highest Sales State: Uttar Pradesh
